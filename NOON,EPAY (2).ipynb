# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df_NOON = pd.read_csv('NOON Historical Data.csv', parse_dates=True)
df_EPAY = pd.read_csv('EPAY Historical Data.csv', parse_dates=True, sep=",")
mergeTable= pd.merge(df_NOON,df_EPAY,how="inner",on='Date')
df = mergeTable[['Price_x','High_x','Price_y']]
df
# Out:
#     Price_x  High_x  Price_y
# 0     65.00   65.00    44.35
# 1     65.00   65.00    44.35
# 2     65.00   65.00    40.79
# 3     65.00   65.00    40.79
# 4     65.00   65.00    38.50
# 5     65.00   65.00    38.50
# 6     65.00   65.00    38.06
# 7     65.00   65.00    38.06
# 8     65.00   65.00    38.14
# 9     65.00   65.00    38.14
# 10    65.00   65.00    39.10
# 11    65.00   65.00    39.10
# 12    65.00   65.00    39.55
# 13    65.00   65.00    39.55
# 14    65.00   65.00    38.22
# 15    65.00   65.00    38.22
# 16    65.00   65.00    40.71
# 17    65.00   65.00    40.71
# 18    65.00   65.00    39.62
# 19    65.00   65.00    39.64
# 20    67.00   67.00    40.23
# 21    63.01   63.10    38.58
# 22    67.00   67.00    39.94
# 23    68.01   68.01    37.90
# 24    68.00   68.00    36.87
# 25    68.00   68.00    37.43
# 26    70.00   70.00    36.49
# 27    72.00   72.00    37.68
# 28    69.47   69.47    37.93

# %%
X = df[['Price_x', 'High_x']]
print(X)
y = df['Price_y']
print(y)
# Out:
#     Price_x  High_x
# 0     65.00   65.00
# 1     65.00   65.00
# 2     65.00   65.00
# 3     65.00   65.00
# 4     65.00   65.00
# 5     65.00   65.00
# 6     65.00   65.00
# 7     65.00   65.00
# 8     65.00   65.00
# 9     65.00   65.00
# 10    65.00   65.00
# 11    65.00   65.00
# 12    65.00   65.00
# 13    65.00   65.00
# 14    65.00   65.00
# 15    65.00   65.00
# 16    65.00   65.00
# 17    65.00   65.00
# 18    65.00   65.00
# 19    65.00   65.00
# 20    67.00   67.00
# 21    63.01   63.10
# 22    67.00   67.00
# 23    68.01   68.01
# 24    68.00   68.00
# 25    68.00   68.00
# 26    70.00   70.00
# 27    72.00   72.00
# 28    69.47   69.47
# 0     44.35
# 1     44.35
# 2     40.79
# 3     40.79
# 4     38.50
# 5     38.50
# 6     38.06
# 7     38.06
# 8     38.14
# 9     38.14
# 10    39.10
# 11    39.10
# 12    39.55
# 13    39.55
# 14    38.22
# 15    38.22
# 16    40.71
# 17    40.71
# 18    39.62
# 19    39.64
# 20    40.23
# 21    38.58
# 22    39.94
# 23    37.90
# ...

# %%
regression = linear_model.LinearRegression()
regression.fit(X, y)
print(regression.coef_)
print(regression.predict([[0, 0]]))
# Out:
# [ 21.85728783 -22.30177701]
# [68.59442311]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Price_x'], df['High_x'], df['Price_y'], c = 'r', marker = 'o')
xx1, xx2 = np.meshgrid(range(1, 4), range(25, 45))
yy = -45.25*xx1 - 0.886*xx2 + 169.23
ax.plot_surface(xx1, xx2, yy, alpha=0.5)
plt.show()
